# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.3.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from lazypredict) (8.5.0)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.13/dist-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.13/dist-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/lib/python3.13/dist-packages (from lazypredict) (4.67.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.13/dist-packages (from lazypredict) (1.6.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.13/dist-packages (from lazypredict) (2.1.3)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.0->lazypredict) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3->lazypredict) (2026.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.0->lazypredict) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.0->lazypredict) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3->lazypredict) (1.17.0)
# Downloading lazypredict-0.3.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.3.0

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =1)
clf = LazyClassifier()
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# LabelPropagation               1.000000           1.000000  1.000000
# LinearDiscriminantAnalysis     1.000000           1.000000  1.000000
# LabelSpreading                 1.000000           1.000000  1.000000
# QuadraticDiscriminantAnalysis  1.000000           1.000000  1.000000
# GaussianNB                     0.973684           0.979167  1.000000
# ExtraTreesClassifier           0.973684           0.979167  1.000000
# ExtraTreeClassifier            0.973684           0.979167  0.982759
# KNeighborsClassifier           0.973684           0.979167  0.998948
# DecisionTreeClassifier         0.973684           0.979167  0.982759
# BaggingClassifier              0.973684           0.979167  1.000000
# AdaBoostClassifier             0.973684           0.979167  0.973932
# SVC                            0.973684           0.979167       NaN
# LGBMClassifier                 0.973684           0.979167  0.984986
# RandomForestClassifier         0.973684           0.979167  1.000000
# LogisticRegression             0.973684           0.979167  1.000000
# NuSVC                          0.973684           0.979167       NaN
# XGBClassifier                  0.947368           0.958333  0.971972
# SGDClassifier                  0.921053           0.937500       NaN
# LinearSVC                      0.894737           0.916667       NaN
# NearestCentroid                0.894737           0.900463  1.000000
# Perceptron                     0.868421           0.895833       NaN
# CalibratedClassifierCV         0.815789           0.854167  0.979335
# RidgeClassifierCV              0.789474           0.833333       NaN
# RidgeClassifier                0.789474           0.833333       NaN
# BernoulliNB                    0.789474           0.817130  0.929281
# PassiveAggressiveClassifier    0.763158           0.812500       NaN
# DummyClassifier                0.236842           0.333333  0.500000
#
#                                F1 Score  Precision    Recall  Time Taken
# Model
# LabelPropagation               1.000000   1.000000  1.000000    0.023901
# LinearDiscriminantAnalysis     1.000000   1.000000  1.000000    0.022555
# LabelSpreading                 1.000000   1.000000  1.000000    0.023346
# QuadraticDiscriminantAnalysis  1.000000   1.000000  1.000000    0.039732
# GaussianNB                     0.973952   0.976316  0.973684    0.022095
# ExtraTreesClassifier           0.973952   0.976316  0.973684    0.142435
# ExtraTreeClassifier            0.973952   0.976316  0.973684    0.027102
# KNeighborsClassifier           0.973952   0.976316  0.973684    0.023904
# DecisionTreeClassifier         0.973952   0.976316  0.973684    0.035871
# BaggingClassifier              0.973952   0.976316  0.973684    0.047937
# AdaBoostClassifier             0.973952   0.976316  0.973684    0.133332
# SVC                            0.973952   0.976316  0.973684    0.020253
# LGBMClassifier                 0.973952   0.976316  0.973684    0.045092
# RandomForestClassifier         0.973952   0.976316  0.973684    0.420037
# LogisticRegression             0.973952   0.976316  0.973684    0.030989
# NuSVC                          0.973952   0.976316  0.973684    0.029344
# XGBClassifier                  0.946794   0.951880  0.947368    0.055801
# SGDClassifier                  0.922608   0.940789  0.921053    0.024868
# LinearSVC                      0.896787   0.927126  0.894737    0.019275
# NearestCentroid                0.896491   0.905332  0.894737    0.031626
# Perceptron                     0.866295   0.902689  0.868421    0.062956
# CalibratedClassifierCV         0.815789   0.896382  0.815789    0.079446
# RidgeClassifierCV              0.786775   0.888545  0.789474    0.032734
# RidgeClassifier                0.786775   0.888545  0.789474    0.064012
# BernoulliNB                    0.785692   0.831955  0.789474    0.023133
# PassiveAggressiveClassifier    0.737261   0.832756  0.763158    0.038233
# DummyClassifier                0.090705   0.056094  0.236842    0.033326

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(models.index, models['Accuracy'])
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np
from sklearn.datasets import fetch_california_housing
X, y = fetch_california_housing(return_X_y=True, as_frame=True)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.1,random_state =1)
reg = LazyRegressor()
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
#                                Adjusted R-Squared    R-Squared       RMSE  \
# Model
# XGBRegressor                             0.835667     0.836305   0.469177
# LGBMRegressor                            0.832418     0.833068   0.473793
# HistGradientBoostingRegressor            0.828649     0.829313   0.479092
# RandomForestRegressor                    0.812115     0.812844   0.501673
# ExtraTreesRegressor                      0.809712     0.810450   0.504871
# BaggingRegressor                         0.799337     0.800115   0.518452
# MLPRegressor                             0.783910     0.784748   0.538012
# GradientBoostingRegressor                0.781889     0.782734   0.540523
# NuSVR                                    0.745389     0.746376   0.584001
# SVR                                      0.743362     0.744357   0.586321
# KNeighborsRegressor                      0.690845     0.692043   0.643522
# DecisionTreeRegressor                    0.612106     0.613611   0.720827
# ElasticNetCV                             0.599548     0.601101   0.732403
# LassoCV                                  0.599545     0.601098   0.732406
# LarsCV                                   0.599393     0.600946   0.732544
# LassoLarsCV                              0.599393     0.600946   0.732544
# RidgeCV                                  0.599310     0.600864   0.732620
# HuberRegressor                           0.599244     0.600798   0.732681
# BayesianRidge                            0.599239     0.600793   0.732685
# Ridge                                    0.599233     0.600787   0.732691
# LassoLarsIC                              0.599224     0.600778   0.732699
# Lars                                     0.599224     0.600778   0.732699
# TransformedTargetRegressor               0.599224     0.600778   0.732699
# LinearRegression                         0.599224     0.600778   0.732699
# LinearSVR                                0.598053     0.599612   0.733769
# OrthogonalMatchingPursuitCV              0.594085     0.595659   0.737382
# SGDRegressor                             0.540944     0.542724   0.784165
# ExtraTreeRegressor                       0.535528     0.537330   0.788777
# OrthogonalMatchingPursuit                0.473995     0.476035   0.839401
# PoissonRegressor                         0.446211     0.448358   0.861285
# AdaBoostRegressor                        0.442738     0.444899   0.863982
# RANSACRegressor                          0.426536     0.428760   0.876451
# TweedieRegressor                         0.395004     0.397350   0.900225
# GammaRegressor                           0.381123     0.383523   0.910493
# PassiveAggressiveRegressor               0.264452     0.267304   0.992614
# ElasticNet                               0.200488     0.203588   1.034873
# DummyRegressor                          -0.004788    -0.000891   1.160144
# LassoLars                               -0.004788    -0.000891   1.160144
# Lasso                                   -0.004788    -0.000891   1.160144
# QuantileRegressor                       -0.045968    -0.041911   1.183679
# KernelRidge                             -2.613568    -2.599555   2.200102
# GaussianProcessRegressor             -4467.893034 -4450.563347  77.370368
#
#                                Time Taken
# Model
# XGBRegressor                     0.429785
# LGBMRegressor                    0.278622
# HistGradientBoostingRegressor    0.441436
# RandomForestRegressor           24.341438
# ExtraTreesRegressor              6.625016
# BaggingRegressor                 2.474547
# MLPRegressor                     8.708412
# GradientBoostingRegressor        6.903218
# NuSVR                           21.303377
# SVR                             17.776385
# KNeighborsRegressor              0.281514
# DecisionTreeRegressor            0.412682
# ElasticNetCV                     0.296518
# LassoCV                          0.267751
# LarsCV                           0.057654
# LassoLarsCV                      0.063181
# RidgeCV                          0.037239
# HuberRegressor                   0.141468
# BayesianRidge                    0.023763
# Ridge                            0.021793
# LassoLarsIC                      0.032032
# Lars                             0.021734
# TransformedTargetRegressor       0.020068
# LinearRegression                 0.022534
# LinearSVR                        1.326223
# OrthogonalMatchingPursuitCV      0.038891
# SGDRegressor                     0.037190
# ExtraTreeRegressor               0.115111
# OrthogonalMatchingPursuit        0.015285
# PoissonRegressor                 0.030165
# AdaBoostRegressor                1.941355
# RANSACRegressor                  0.213253
# TweedieRegressor                 0.026356
# GammaRegressor                   0.027355
# PassiveAggressiveRegressor       0.049670
# ElasticNet                       0.017074
# DummyRegressor                   0.014282
# LassoLars                        0.018993
# Lasso                            0.020965
# QuantileRegressor               15.249277
# KernelRidge                     79.046558
# GaussianProcessRegressor       189.718125

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(models.index, models['R-Squared'],'-s')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **EXERCISE 3.20**

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

X, y = load_wine(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)

plt.figure(figsize=(10, 5))
plt.plot(models.index, models['Accuracy'])
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# CalibratedClassifierCV         1.000000           1.000000  1.000000
# GaussianNB                     1.000000           1.000000  1.000000
# LinearDiscriminantAnalysis     1.000000           1.000000  1.000000
# RidgeClassifierCV              1.000000           1.000000       NaN
# NuSVC                          1.000000           1.000000       NaN
# LogisticRegression             1.000000           1.000000  1.000000
# RidgeClassifier                1.000000           1.000000       NaN
# LabelPropagation               0.977778           0.980392  0.985450
# KNeighborsClassifier           0.977778           0.980392  0.980688
# ExtraTreesClassifier           0.977778           0.980392  0.999206
# AdaBoostClassifier             0.977778           0.980392  1.000000
# LGBMClassifier                 0.977778           0.980392  1.000000
# XGBClassifier                  0.977778           0.980392  1.000000
# RandomForestClassifier         0.977778           0.980392  1.000000
# QuadraticDiscriminantAnalysis  0.977778           0.980392  1.000000
# Perceptron                     0.977778           0.980392       NaN
# NearestCentroid                0.977778           0.980392  0.997590
# LabelSpreading                 0.977778           0.980392  0.988624
# PassiveAggressiveClassifier    0.977778           0.966667       NaN
# SVC                            0.977778           0.966667       NaN
# LinearSVC                      0.977778           0.966667       NaN
# SGDClassifier                  0.977778           0.966667       NaN
# DecisionTreeClassifier         0.955556           0.960784  0.967196
# BaggingClassifier              0.933333           0.942266  0.990388
# BernoulliNB                    0.933333           0.928540  0.989753
# ExtraTreeClassifier            0.911111           0.910022  0.927910
# DummyClassifier                0.377778           0.333333  0.500000
#
#                                F1 Score  Precision    Recall  Time Taken
# Model
# CalibratedClassifierCV         1.000000   1.000000  1.000000    0.077812
# GaussianNB                     1.000000   1.000000  1.000000    0.022181
# LinearDiscriminantAnalysis     1.000000   1.000000  1.000000    0.021633
# RidgeClassifierCV              1.000000   1.000000  1.000000    0.020583
# NuSVC                          1.000000   1.000000  1.000000    0.029753
# LogisticRegression             1.000000   1.000000  1.000000    0.033403
# RidgeClassifier                1.000000   1.000000  1.000000    0.021062
# LabelPropagation               0.977741   0.978947  0.977778    0.023352
# KNeighborsClassifier           0.977741   0.978947  0.977778    0.024556
# ExtraTreesClassifier           0.977741   0.978947  0.977778    0.142448
# AdaBoostClassifier             0.977741   0.978947  0.977778    0.142311
# LGBMClassifier                 0.977741   0.978947  0.977778    0.059539
# XGBClassifier                  0.977741   0.978947  0.977778    0.061325
# RandomForestClassifier         0.977741   0.978947  0.977778    0.195360
# QuadraticDiscriminantAnalysis  0.977741   0.978947  0.977778    0.029477
# Perceptron                     0.977741   0.978947  0.977778    0.022757
# NearestCentroid                0.977741   0.978947  0.977778    0.031108
# LabelSpreading                 0.977741   0.978947  0.977778    0.023443
# PassiveAggressiveClassifier    0.977510   0.979012  0.977778    0.028991
# SVC                            0.977510   0.979012  0.977778    0.019876
# LinearSVC                      0.977510   0.979012  0.977778    0.019415
# SGDClassifier                  0.977510   0.979012  0.977778    0.020320
# DecisionTreeClassifier         0.954996   0.958745  0.955556    0.030639
# BaggingClassifier              0.932852   0.933965  0.933333    0.051805
# BernoulliNB                    0.933701   0.935802  0.933333    0.023551
# ExtraTreeClassifier            0.912043   0.916821  0.911111    0.028422
# DummyClassifier                0.207168   0.142716  0.377778    0.028933

# %% [markdown]
# **EXERCISE 3.21**

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 1. Load Dataset Regresi baru (Diabetes)
X, y = load_diabetes(return_X_y=True, as_frame=True)

# 2. Split Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# 3. Model & Fit
reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
print(models)

# 4. Plot Hasil R-Squared
plt.figure(figsize=(10, 5))
plt.plot(models.index, models['R-Squared'], '-s')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
#                                Adjusted R-Squared  R-Squared        RMSE  \
# Model
# PassiveAggressiveRegressor               0.151031   0.343979   56.487839
# LinearRegression                         0.116748   0.317487   57.617111
# TransformedTargetRegressor               0.116748   0.317487   57.617111
# ElasticNet                               0.115076   0.316195   57.671616
# Ridge                                    0.114627   0.315848   57.686252
# ElasticNetCV                             0.113984   0.315351   57.707199
# HuberRegressor                           0.112070   0.313872   57.769479
# BayesianRidge                            0.112055   0.313861   57.769958
# RidgeCV                                  0.111446   0.313390   57.789789
# LassoLarsCV                              0.104312   0.307877   58.021316
# LassoCV                                  0.104179   0.307774   58.025624
# SGDRegressor                             0.103815   0.307493   58.037411
# LarsCV                                   0.101501   0.305706   58.112271
# TweedieRegressor                         0.101277   0.305532   58.119512
# LassoLarsIC                              0.098306   0.303237   58.215506
# Lasso                                    0.097293   0.302454   58.248197
# LassoLars                                0.097287   0.302449   58.248402
# RANSACRegressor                          0.083803   0.292030   58.681808
# OrthogonalMatchingPursuitCV              0.077510   0.287167   58.883000
# PoissonRegressor                         0.063947   0.276686   59.314282
# GammaRegressor                           0.047231   0.263770   59.841556
# GradientBoostingRegressor                0.037228   0.256039   60.154889
# AdaBoostRegressor                        0.025185   0.246734   60.529931
# LGBMRegressor                            0.000779   0.227875   61.282975
# ExtraTreesRegressor                     -0.009720   0.219762   61.604093
# HistGradientBoostingRegressor           -0.018146   0.213251   61.860589
# NuSVR                                   -0.097559   0.151886   64.227794
# KNeighborsRegressor                     -0.108277   0.143604   64.540640
# RandomForestRegressor                   -0.120883   0.133863   64.906671
# SVR                                     -0.144191   0.115853   65.578020
# BaggingRegressor                        -0.154444   0.107930   65.871187
# LinearSVR                               -0.215840   0.060488   67.600086
# OrthogonalMatchingPursuit               -0.293132   0.000761   69.715704
# DummyRegressor                          -0.307625  -0.010438   70.105290
# QuantileRegressor                       -0.395634  -0.078444   72.426054
# XGBRegressor                            -0.452190  -0.122147   73.878982
# Lars                                    -0.487184  -0.149188   74.763827
# ExtraTreeRegressor                      -0.752008  -0.353824   81.147876
# GaussianProcessRegressor                -1.538318  -0.961427   97.674702
# DecisionTreeRegressor                   -1.609553  -1.016473   99.035796
# MLPRegressor                            -2.313499  -1.560431  111.596996
# KernelRidge                             -6.550102  -4.834169  168.455622
#
#                                Time Taken
# Model
# PassiveAggressiveRegressor       0.010798
# LinearRegression                 0.010162
# TransformedTargetRegressor       0.011802
# ElasticNet                       0.010422
# Ridge                            0.010639
# ElasticNetCV                     0.065947
# HuberRegressor                   0.032648
# BayesianRidge                    0.011012
# RidgeCV                          0.011878
# LassoLarsCV                      0.023984
# LassoCV                          0.073337
# SGDRegressor                     0.011169
# LarsCV                           0.063973
# TweedieRegressor                 0.013328
# LassoLarsIC                      0.013598
# Lasso                            0.012709
# LassoLars                        0.012771
# RANSACRegressor                  0.123509
# OrthogonalMatchingPursuitCV      0.015013
# PoissonRegressor                 0.016040
# GammaRegressor                   0.013475
# GradientBoostingRegressor        0.205548
# AdaBoostRegressor                0.134416
# LGBMRegressor                    0.038672
# ExtraTreesRegressor              0.230079
# HistGradientBoostingRegressor    0.123267
# NuSVR                            0.022157
# KNeighborsRegressor              0.014911
# RandomForestRegressor            0.421361
# SVR                              0.018905
# BaggingRegressor                 0.057565
# LinearSVR                        0.010275
# OrthogonalMatchingPursuit        0.011014
# DummyRegressor                   0.009467
# QuantileRegressor                0.047585
# XGBRegressor                     0.169316
# Lars                             0.036118
# ExtraTreeRegressor               0.012146
# GaussianProcessRegressor         0.028573
# DecisionTreeRegressor            0.015410
# MLPRegressor                     0.257062
# KernelRidge                      0.031998
